# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\pkana\iNeuron\PROJECTS\StoreSalePrediction\sales\artifact\data_ingestion\Ingested_data\Train.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
schema=dict()

# %%
column=dict()
for col in df.columns:
    column[col]=str(df[col].dtype)

# %%
schema["column"] = column

# %%
numerical_columns=list(df.select_dtypes(exclude='object').columns)

# %%
numerical_columns
# Out:
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Outlet_Sales']

# %%
schema["numerical_columns"]=numerical_columns

# %%
categorical_columns=list(df.select_dtypes(include=['object']).columns)

# %%
categorical_columns
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
schema["categorical_columns"]=categorical_columns

# %%
target_column="Item_Outlet_Sales"

# %%
schema["target_column"]=target_column

# %%
cat_df=df.select_dtypes(include=['object'])

# %%
cat_df
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
list(cat_df["Item_Fat_Content"].unique())
# Out:
# ['Low Fat', 'Regular', 'low fat', 'LF', 'reg']

# %%
domain_values=dict()
for col in cat_df.columns:
    domain_values[col]=list(cat_df[col].unique())

# %%
domain_values
# Out:
# {'Item_Identifier': ['FDA15',
#   'DRC01',
#   'FDN15',
#   'FDX07',
#   'NCD19',
#   'FDP36',
#   'FDO10',
#   'FDP10',
#   'FDH17',
#   'FDU28',
#   'FDY07',
#   'FDA03',
#   'FDX32',
#   'FDS46',
#   'FDF32',
#   'FDP49',
#   'NCB42',
#   'DRI11',
#   'FDU02',
#   'FDN22',
#   'FDW12',
#   'NCB30',
#   'FDC37',
#   'FDR28',
#   'NCD06',
#   'FDV10',
#   'DRJ59',
#   'FDE51',
#   'FDC14',
#   'FDV38',
#   'NCS17',
#   'FDP33',
#   'FDO23',
#   'DRH01',
#   'NCX29',
#   'FDV20',
#   'DRZ11',
#   'FDX10',
#   'FDB34',
#   'FDK43',
#   'FDA46',
#   'FDC02',
#   'FDL50',
#   'FDM39',
#   'NCP05',
#   'FDV49',
#   'FDL12',
#   'FDS02',
#   'NCL17',
#   'FDM40',
#   'FDR13',
#   'FDA43',
#   'NCP18',
#   'FDK21',
#   'NCX54',
#   'DRK35',
#   'FDY21',
#   'FDI26',
#   'FDM20',
#   'FDV27',
#   'FDF09',
#   'FDY40',
#   'FDY45',
#   'FDC46',
#   'FDH19',
#   'FDZ03',
#   'DRH37',
#   'NCI17',
#   'FDJ58',
#   'FDH35',
#   'FDG02',
#   'NCZ18',
#   'FDC29',
#   'FDQ10',
#   'FDN48',
# ...

# %%
schema["domain_values"]=domain_values

# %%
schema
# Out:
# {'column': {'Item_Identifier': 'object',
#   'Item_Weight': 'float64',
#   'Item_Fat_Content': 'object',
#   'Item_Visibility': 'float64',
#   'Item_Type': 'object',
#   'Item_MRP': 'float64',
#   'Outlet_Identifier': 'object',
#   'Outlet_Establishment_Year': 'int64',
#   'Outlet_Size': 'object',
#   'Outlet_Location_Type': 'object',
#   'Outlet_Type': 'object',
#   'Item_Outlet_Sales': 'float64'},
#  'numerical_columns': ['Item_Weight',
#   'Item_Visibility',
#   'Item_MRP',
#   'Outlet_Establishment_Year',
#   'Item_Outlet_Sales'],
#  'categorical_columns': ['Item_Identifier',
#   'Item_Fat_Content',
#   'Item_Type',
#   'Outlet_Identifier',
#   'Outlet_Size',
#   'Outlet_Location_Type',
#   'Outlet_Type'],
#  'target_column': 'Item_Outlet_Sales',
#  'domain_values': {'Item_Identifier': ['FDA15',
#    'DRC01',
#    'FDN15',
#    'FDX07',
#    'NCD19',
#    'FDP36',
#    'FDO10',
#    'FDP10',
#    'FDH17',
#    'FDU28',
#    'FDY07',
#    'FDA03',
#    'FDX32',
#    'FDS46',
# ...

# %%
from sales.utils.utils import read_yaml_file

# %%
from sales.utils.utils import write_yaml_file

# %%
import os

# %%
file_dir=r"C:\Users\pkana\iNeuron\PROJECTS\StoreSalePrediction\config"

# %%
file_name="schema.yaml"

# %%
file_path=os.path.join(file_dir,file_name)

# %%
write_yaml_file(file_path,schema)
